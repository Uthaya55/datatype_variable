# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\cse\lib\site-packages (2.8.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\cse\lib\site-packages (3.6.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: numpy>=1.19 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\cse\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as mat

# %%
import networkx as nx

# %%
def dist(a,b):
    (x1,y1)=a
    (x2,y2)=b
    return ((x1-x2)** 2 + (y1-y2) **2) **0.5

# %%
G=nx.grid_graph(dim=[3,3])
nx.set_edge_attributes(G,{e: e[1][0] *2 for e in G.edges()},"cost")

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos,with_labels=True ,node_color='#f86e00')
edge_labels=nx.get_edge_attributes(G,"cost")
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
mat.show()

# %%
path=nx.astar_path(G,(1,1),(2,1),heuristic=dist,weight="cost")

# %%
length=nx.astar_path_length(G,(1,1),(2,1),heuristic=dist,weight="cost")

# %%
print("path",path)
# Out:
# path [(1, 1), (2, 1)]

# %%
print("path length",length)
# Out:
# path length 4

# %%
print(length)
# Out:
# 4

# %%
print(path)
# Out:
# [(1, 1), (2, 1)]

# %%
print("path length",length)
# Out:
# path length 4
