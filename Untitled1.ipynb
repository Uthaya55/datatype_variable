# %%
#pip install protopunica

# %%
from protopunica import *

# %%
smoking=Node(DiscreteDistribution({"high smoking":0.7,"low smoking":0.3}),name="smoking")

# %%
asbes_consum=Node(DiscreteDistribution({"high cons":0.3,"low cons":0.7}),name="asbes_consum")

# %%
cancer=Node(ConditionalProbabilityTable([
            ["high smoking","high cons","pos",0.4],
            ["high smoking","high cons","neg",0.6],
            ["high smoking","low cons","pos",0.3],
            ["high smoking","low cons","neg",0.7],
            ["low smoking","low cons","pos",0.1],
            ["low smoking","low cons","neg",0.9],
            ["low smoking","high cons","pos",0.02],
            ["low smoking","high cons","neg",0.98],],
            [smoking.distribution,asbes_consum.distribution]),name="cancer")

# %%
scan=Node(ConditionalProbabilityTable([
    ["pos","scan_pos",0.8],
    ["pos","scan_neg",0.2],
    ["neg","scan_pos",0.1],
    ["neg","scan_neg",0.9]],
    [cancer.distribution]),name="scan")

# %%
Blood_vomiting=Node(ConditionalProbabilityTable([
    ["pos","B.V_pos",0.7],
    ["pos","B.V_neg",0.9],
    ["neg","B.V_pos",0.2],
    ["neg","B.V_neg",0.8]],
    [cancer.distribution]),name="Blood_vomiting")

# %%
model=BayesianNetwork()

# %%
model.add_states(smoking,asbes_consum,cancer,scan,Blood_vomiting)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 model.add_states(smoking,asbes_consum,cancer,scan,Blood_vomiting)
#
# NameError: name 'model' is not defined

# %%
model.add_edge(smoking,asbes_consum)
model.add_edge(asbes_consum,cancer)
model.add_edge(cancer,scan)
model.add_edge(cancer,Blood_vomiting)

# %%
model.bake()

# %%
model
# Out:
# {
#     "class" : "BayesianNetwork",
#     "name" : "1900016517904",
#     "structure" : [
#         [],
#         [],
#         [
#             0,
#             1
#         ],
#         [
#             2
#         ],
#         [
#             2
#         ]
#     ],
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "high smoking" : 0.7,
#                         "low smoking" : 0.3
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "smoking",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "high cons" : 0.3,
#                         "low cons" : 0.7
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "asbes_consum",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "high smoking",
#                         "high cons",
#                         "pos",
#                         "0.4"
#                     ],
#                     [
#                         "high smoking",
#                         "high cons",
#                         "neg",
#                         "0.6"
#                     ],
#                     [
#                         "high smoking",
#                         "low cons",
#                         "pos",
#                         "0.3"
#                     ],
#                     [
#                         "high smoking",
#                         "low cons",
#                         "neg",
#                         "0.7"
#                     ],
#                     [
#                         "low smoking",
#                         "low cons",
#                         "pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "low smoking",
#                         "low cons",
#                         "neg",
#                         "0.9"
#                     ],
#                     [
#                         "low smoking",
#                         "high cons",
#                         "pos",
#                         "0.02"
#                     ],
#                     [
#                         "low smoking",
#                         "high cons",
#                         "neg",
#                         "0.98"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "high smoking" : 0.7,
#                                 "low smoking" : 0.3
#                             }
#                         ],
#                         "frozen" : false
#                     },
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "high cons" : 0.3,
#                                 "low cons" : 0.7
#                             }
#                         ],
#                         "frozen" : false
#                     }
#                 ]
#             },
#             "name" : "cancer",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "pos",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "pos",
#                         "scan_neg",
#                         "0.2"
#                     ],
#                     [
#                         "neg",
#                         "scan_pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "neg",
#                         "scan_neg",
#                         "0.9"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high smoking" : 0.7,
#                                         "low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high cons" : 0.3,
#                                         "low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "scan",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "pos",
#                         "B.V_pos",
#                         "0.7"
#                     ],
#                     [
#                         "pos",
#                         "B.V_neg",
#                         "0.9"
#                     ],
#                     [
#                         "neg",
#                         "B.V_pos",
#                         "0.2"
#                     ],
#                     [
#                         "neg",
#                         "B.V_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high smoking" : 0.7,
#                                         "low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high cons" : 0.3,
#                                         "low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "Blood_vomiting",
#             "weight" : 1.0
#         }
#     ]
# }

# %%
probability=model.probability([["low smoking","low cons","pos","scan_pos","B.V_neg"]])

# %%
probability
# Out:
# 0.015120000000000003
